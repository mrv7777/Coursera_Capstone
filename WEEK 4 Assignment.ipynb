# %% [markdown]
# # Keshari Nath Chaudhary

# %% [markdown]
# ### Introduction: A description of the problem and a discussion of the background

# %% [markdown]
# 1. In Module 3, we explored New York City and the city of Toronto and segmented and clustered their neighborhoods. Both cities are very diverse and are the financial capitals of their respective countries.
# 2. One interesting idea would be to compare the neighborhoods of the two cities and determine how similar or dissimilar they are.
# 3. In this assignment we will compare the neighborhoods of the two indian cities namely Hyderabad and Mumbai
# 4. Is Hyderabad more like Toronto or Mumbai or some other multicultural city?
# 5. In Hyderabad, if someone is looking to open a restaurant, where would we recommend that they open it? Similarly, if a contractor is trying to start their own business, where would you recommend that they setup their office? and other important points will be discussed

# %% [markdown]
# ### Extracting the data¶

# %% [markdown]
# List of Cafes and foodstalls of Hyderabad with their lattitude and longitude,
# List of Hotels, Book stores,Restaurant, Bakaries, and all relavant locations,
# All data is limited with in 10km radius

# %%
import json 
import requests 
from pandas.io.json import json_normalize 
import numpy as np 
import time
import pandas as pd 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim 
# !conda install -c conda-forge folium=0.5.0 --yes
import folium 
print('Libraries imported.')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Libraries imported.

# %% [markdown]
# ### Extracting the geograpical coordinates of Hyderabad through geolocator¶

# %%
address = 'Hyderabad,HYD'
geolocator = Nominatim(user_agent="HYD_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinates of' ,address,'are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinates of Hyderabad,HYD are 17.3140928, 78.4745688.

# %%
neighborhood_latitude=latitude
neighborhood_longitude=longitude

# %% [markdown]
# ### Using Foursquare credentials to analyse the neighbourhood in Hyderabad

# %%
CLIENT_ID = 'W0TOR4YGZ3KRYLETUOX2SBBLAAAXOCQECJ31DGYWWEE5PYSO'
CLIENT_SECRET = 'EVNNFIUBUFIANIFDQ2P5KD2WN4J0WNS54VJCYO3Y0VENKDZ5' # your Foursquare Secret
VERSION = '20180604' #your version

# %%
radius = 10000
limit = 200 
# importing the data with URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius,
    limit)
results = requests.get(url).json()

# %% [markdown]
# ### Determining the catogories of each location in data

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [markdown]
# ### Showing the list of venues¶

# %%
venues = results['response']['groups'][0]['items']
    
HYD_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
HYD_venues =HYD_venues.loc[:, filtered_columns]
# filter the category for each row
HYD_venues['venue.categories'] = HYD_venues.apply(get_category_type, axis=1)
# clean columns
HYD_venues.columns = [col.split(".")[-1] for col in HYD_venues.columns]
HYD_venues.head(100)
# Out:
# <ipython-input-13-9c66c6406e1f>:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   HYD_venues = json_normalize(venues) # flatten JSON
#                                                  name  \
# 0                                Taj Falaknuma Palace
# 1                                   Hotel Shah Ghouse
# 2                                   Chowmahala Palace
# 3                                             Shadaab
# 4                                         Pista house
# 5                                     Swagath Tiffins
# 6                                        Jade Terrace
# 7                                           Charminar
# 8                                     Laxman Ki Bandi
# 9                              Decathlon Sports Store
# 10                                            Pragati
# 11                                  Asian Shiva ganga
# 12                                     Mayur Pan Shop
# 13                                    King & Cardinal
# 14                                           Spencers
# 15                                      Santosh Dhaba
# 16                                       Ram ki Bandi
# 17                             Cafe Niloufer & Bakers
# 18                                Minerva Coffee Shop
# 19                                       Hotel Sohail
# 20                                  Salar Jung Museum
# 21                                     Karachi Bakery
# 22                                  Eeshwar Multiplex
# 23                                         Nizam club
# 24                                         Cafe Bahar
# 25                 Siraj's International Juice Center
# 26                                      Subhan Bakery
# 27                                       Hotel Nayaab
# 28                                         Gokul Chat
# 29                                            Celesté
# 30                                  Gokul Chat Center
# 31                                       Almond House
# 32                                       Bombay Juice
# 33                                         McDonald's
# 34                                    Taj Mahal Hotel
# 35                                          Hollywood
# 36                                           Blue Fox
# 37                                     Hotel Megacity
# 38                      Meco MotorSport  - Go Karting
# 39                                     Moon Bean Cafe
# 40                                      Bombay Bakery
# 41                                      Santosh Dabha
# 42                                             Abid's
# 43  Rajiv Gandhi International Airport (HYD) (Raji...
# 44                                             D Mart
# 45                                  Mohini Restaurant
# 46                    New Madhushala Bar & Restaurant
# 47                                        Grand Hotel
# 48                                      Pariwar Dhaba
# 49                                   Salarjung Museum
# 50                          Novotel Hyderabad Airport
# 51                                       Costa Coffee
# 52                        Mayur Pan Shop Himayatnagar
# 53                                         McDonald's
# 54                                   Bajrang Pan Shop
# 55                                         The Square
# 56                                                KFC
# 57                                     Karachi Bakery
# 58           Papadams Blue Restaurant & Banquet Halls
# 59                                       Idly Factory
# 60                                     Domino's Pizza
# 61                       Inox Maheshwari Paremeshwari
# 62                   Rahul tiffins & fast food centre
# 63                                 The Chocolate Room
# 64                                         creamstone
# 65                                     Matam Al-Arabi
# 66                               Yum Yum Tree Arabian
# 67                          Kotak Mahindra Bank - ATM
# 68                                     Domino's Pizza
# 69                                     Miraj Theatres
# 70                              Vijayalakshmi Theatre
# 71                                             Subway
# 72                                                KFC
# 73                                   SVM Bowling Ally
# 74                                          Pizza Hut
# 75                                     Domino's Pizza
# 76                                Paradise Food Court
# 77                                       Sohail Waves
# 78                                    Cafe Coffee Day
# 79                                 Real Arabian Dhaba
# 80                                     Domino's Pizza
# 81                                    Cafe Coffee Day
# 82                                         McDonald's
# 83                                     Shopper's Stop
# 84                                     Taste of India
# 85                                  WH Smith Bookshop
# 86                                    Barista Lavazza
# 87                                        The DESTINO
# 88                      Kholani's The Taste Of Nizams
# 89                                       Idli Factory
# 90                                     Serena Tiffins
# 91                             Haldi Diner Restaurant
# 92                        Padma Vamshi Textile Market
# 93                                        Network Bar
# 94                                    Indian Paradise
# 95                                       Pick Point D
# 96                                       Pick Point C
# 97                       APSRTC Pushpak Airport Liner
# 98                                 Uber Pick Up Point
# 99                                    The Food Street
#
#                        categories        lat        lng
# 0                          Resort  17.330118  78.467460
# 1                     Snack Place  17.347899  78.470986
# 2                  History Museum  17.359300  78.471617
# 3                           Diner  17.368661  78.475572
# 4               Indian Restaurant  17.356609  78.473637
# 5   Vegetarian / Vegan Restaurant  17.344639  78.508231
# 6                  Breakfast Spot  17.330542  78.467510
# 7             Monument / Landmark  17.361555  78.474677
# 8         South Indian Restaurant  17.378895  78.463973
# 9             Sporting Goods Shop  17.242370  78.434798
# 10        South Indian Restaurant  17.388088  78.481134
# 11                      Multiplex  17.361122  78.523215
# 12                      Juice Bar  17.388894  78.480578
# 13                   Burger Joint  17.400678  78.488575
# 14                  Shopping Mall  17.369601  78.429146
# 15              Indian Restaurant  17.388485  78.479509
# 16                     Food Truck  17.386050  78.476207
# 17                           Café  17.399715  78.462881
# 18              Indian Restaurant  17.401410  78.485672
# 19              Indian Restaurant  17.372829  78.499298
# 20                 History Museum  17.371773  78.480636
# 21                         Bakery  17.383454  78.475075
# 22                  Movie Theater  17.366638  78.427328
# 23                         Lounge  17.403221  78.468729
# 24              Indian Restaurant  17.399595  78.478566
# 25                      Juice Bar  17.395579  78.442701
# 26                         Bakery  17.392412  78.464712
# 27                     Food Court  17.368504  78.477480
# 28                    Snack Place  17.397860  78.492700
# 29             Italian Restaurant  17.330125  78.467442
# 30                    Chaat Place  17.384716  78.483152
# 31                   Dessert Shop  17.401319  78.485872
# 32                      Juice Bar  17.387968  78.480779
# 33           Fast Food Restaurant  17.401162  78.486509
# 34                          Hotel  17.391942  78.476915
# 35                     Shoe Store  17.389916  78.476241
# 36              Indian Restaurant  17.401401  78.485653
# 37                      Hotel Bar  17.401133  78.475990
# 38                      Racetrack  17.239713  78.427797
# 39                           Café  17.368964  78.517230
# 40                         Bakery  17.394869  78.475475
# 41                          Diner  17.391209  78.477575
# 42                   Neighborhood  17.390543  78.475724
# 43                        Airport  17.235295  78.429899
# 44               Department Store  17.371147  78.505046
# 45              Indian Restaurant  17.401926  78.476153
# 46                            Bar  17.397948  78.484073
# 47              Indian Restaurant  17.387760  78.477577
# 48                     Food Court  17.319891  78.429995
# 49                 History Museum  17.371527  78.478283
# 50                          Hotel  17.242325  78.454468
# 51                           Café  17.236827  78.429342
# 52                     Restaurant  17.400975  78.485509
# 53           Fast Food Restaurant  17.288892  78.416189
# 54                     Smoke Shop  17.402279  78.477165
# 55                          Diner  17.242296  78.454518
# 56           Fast Food Restaurant  17.345930  78.552375
# 57                         Bakery  17.235138  78.430288
# 58              Indian Restaurant  17.366923  78.538199
# 59  Vegetarian / Vegan Restaurant  17.235055  78.430981
# 60                    Pizza Place  17.342000  78.552000
# 61                      Multiplex  17.390728  78.488352
# 62                 Breakfast Spot  17.403185  78.480070
# 63                    Coffee Shop  17.401617  78.485403
# 64                 Ice Cream Shop  17.399652  78.491890
# 65              Afghan Restaurant  17.301213  78.475706
# 66       Mediterranean Restaurant  17.309767  78.475790
# 67                            ATM  17.236450  78.429920
# 68                    Pizza Place  17.381000  78.493000
# 69                  Movie Theater  17.367950  78.536516
# 70                  Movie Theater  17.343858  78.554361
# 71                 Sandwich Place  17.236599  78.429579
# 72           Fast Food Restaurant  17.372814  78.505762
# 73                  Bowling Alley  17.367892  78.537094
# 74                    Pizza Place  17.236604  78.429977
# 75                    Pizza Place  17.371564  78.511066
# 76          Hyderabadi Restaurant  17.360841  78.544294
# 77      Middle Eastern Restaurant  17.372298  78.499453
# 78                    Coffee Shop  17.236465  78.429542
# 79      Middle Eastern Restaurant  17.300175  78.475507
# 80                    Pizza Place  17.365000  78.546000
# 81                           Café  17.369760  78.516115
# 82           Fast Food Restaurant  17.236702  78.429454
# 83              Accessories Store  17.235213  78.430887
# 84              Indian Restaurant  17.234974  78.430956
# 85                      Bookstore  17.235757  78.429666
# 86                           Café  17.235221  78.430188
# 87                     Hookah Bar  17.369542  78.520331
# 88              Indian Restaurant  17.237322  78.430815
# 89        South Indian Restaurant  17.235129  78.430632
# 90                 Breakfast Spot  17.368088  78.522291
# 91              Indian Restaurant  17.242321  78.454371
# 92                  Shopping Mall  17.365977  78.536284
# 93                           Café  17.235235  78.430137
# 94             Airport Food Court  17.234452  78.431450
# 95                     Taxi Stand  17.238036  78.428759
# 96                     Taxi Stand  17.238464  78.427960
# 97             Light Rail Station  17.237147  78.430149
# 98                     Taxi Stand  17.237288  78.428614
# 99                     Restaurant  17.236838  78.429430

# %%
HYD_venues.shape
# Out:
# (100, 4)
